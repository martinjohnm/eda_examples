# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# number of null values 
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Age cabin and embarked have null values

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot(x='Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# out of 891 peoples in training sample around 350 peoples survived  (38.4%)
#
# we need check other features for better estimate of survival rate . some of the features are age, sex, embarked

# %% [markdown]
# Categorical Features:
# A categorical variable is one that has two or more categories and each value in that feature can be categorised by them.For example, gender is a categorical variable having two categories (male and female). Now we cannot sort or give any ordering to such variables. They are also known as Nominal Variables.
#
# Categorical Features in the dataset: Sex,Embarked.

# %% [markdown]
# Ordinal Features:
# An ordinal variable is similar to categorical values, but the difference between them is that we can have relative ordering or sorting between the values. For eg: If we have a feature like Height with values Tall, Medium, Short, then Height is a ordinal variable. Here we can have a relative sort in the variable.
# ordinbaol feature in data set is pclass

# %% [markdown]
#     Continous Feature:
# A feature is said to be continous if it can take values between any two points or between the minimum or maximum values in the features column.
#
# Continous Features in the dataset: Age

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %% [markdown]
# number males is more than females

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')

sns.countplot(x='Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# The number of men on the ship is lot more than the number of women. Still the number of women saved is almost twice the number of males saved. The survival rates for a women on the ship is around 75% while that for men in around 18-19%.

# %% [markdown]
# # Pclass   ordinal feature

# %%
pd.crosstab(index=data.Pclass,  columns=data.Survived,  margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_63c62_row0_col0, #T_63c62_row1_col1, #T_63c62_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_63c62_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_63c62_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_63c62_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_63c62_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_63c62_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_63c62_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_63c62_row3_col0, #T_63c62_row3_col1, #T_63c62_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_63c62">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_63c62_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_63c62_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_63c62_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63c62_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_63c62_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_63c62_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_63c62_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_63c62_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_63c62_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_63c62_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_63c62_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_63c62_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_63c62_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_63c62_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_63c62_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_63c62_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_63c62_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_63c62_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_63c62_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot(x='Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')

plt.show()

# %% [markdown]
# Passenegers Of Pclass 1 were given a very high priority while rescue. Even though the the number of Passengers in Pclass 3 were a lot higher, still the number of survival from them is very low, somewhere around 25%.
#
# For Pclass 1 %survived is around 63% while for Pclass2 is around 48%.
#
# Lets Dive in little bit more and check for other interesting observations. Lets check survival rate with Sex and Pclass Together.

# %%
data[['Sex','Survived']].groupby(['Sex']).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_beda8_row0_col0, #T_beda8_row0_col1, #T_beda8_row0_col3, #T_beda8_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_beda8_row0_col2, #T_beda8_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_beda8_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_beda8_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_beda8_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_beda8_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_beda8_row2_col1, #T_beda8_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_beda8_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_beda8_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_beda8_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_beda8_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_beda8_row4_col0, #T_beda8_row4_col1, #T_beda8_row4_col2, #T_beda8_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_beda8">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_beda8_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_beda8_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_beda8_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_beda8_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_beda8_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_beda8_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_beda8_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_beda8_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_beda8_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_beda8_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_beda8_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_beda8_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_beda8_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_beda8_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_beda8_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_beda8_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_beda8_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_beda8_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_beda8_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_beda8_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_beda8_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_beda8_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_beda8_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_beda8_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_beda8_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_beda8_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_beda8_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_beda8_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_beda8_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_beda8_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_beda8_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_beda8_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
sns.catplot(x='Pclass',y='Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# Looking at the CrossTab and the FactorPlot, we can easily infer that survival for Women from Pclass1 is about 95-96%, as only 3 out of 94 Women from Pclass1 died.
#
# It is evident that irrespective of Pclass, Women were given first priority while rescue. Even Men from Pclass1 have a very low survival rate.
#
# Looks like Pclass is also an important feature. Lets analyse other features.

# %% [markdown]
# # age continuos feature

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot(x="Pclass",y="Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot(x="Sex",y="Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style type="text/css">
# #T_b6e05_row0_col0, #T_b6e05_row0_col1, #T_b6e05_row0_col3, #T_b6e05_row0_col4, #T_b6e05_row0_col5, #T_b6e05_row0_col7, #T_b6e05_row0_col8, #T_b6e05_row0_col12, #T_b6e05_row0_col15, #T_b6e05_row0_col16, #T_b6e05_row1_col2, #T_b6e05_row1_col6, #T_b6e05_row1_col9, #T_b6e05_row1_col10, #T_b6e05_row1_col11, #T_b6e05_row1_col13, #T_b6e05_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_b6e05_row0_col2, #T_b6e05_row0_col6, #T_b6e05_row0_col9, #T_b6e05_row0_col10, #T_b6e05_row0_col11, #T_b6e05_row0_col13, #T_b6e05_row0_col14, #T_b6e05_row1_col0, #T_b6e05_row1_col1, #T_b6e05_row1_col3, #T_b6e05_row1_col4, #T_b6e05_row1_col5, #T_b6e05_row1_col7, #T_b6e05_row1_col8, #T_b6e05_row1_col12, #T_b6e05_row1_col15, #T_b6e05_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b6e05">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_b6e05_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_b6e05_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_b6e05_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_b6e05_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_b6e05_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_b6e05_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_b6e05_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_b6e05_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_b6e05_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_b6e05_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_b6e05_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_b6e05_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_b6e05_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_b6e05_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_b6e05_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_b6e05_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_b6e05_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6e05_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_b6e05_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b6e05_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_b6e05_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_b6e05_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b6e05_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_b6e05_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_b6e05_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_b6e05_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_b6e05_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_b6e05_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_b6e05_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_b6e05_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_b6e05_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_b6e05_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_b6e05_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_b6e05_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_b6e05_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b6e05_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_b6e05_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_b6e05_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_b6e05_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_b6e05_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_b6e05_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_b6e05_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_b6e05_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_b6e05_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_b6e05_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_b6e05_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_b6e05_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_b6e05_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_b6e05_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_b6e05_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_b6e05_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_b6e05_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_b6e05_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# there are some misspelled Initials like Mlle or Mme that stand for Miss. I will replace them with Miss and same thing for other values.

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Initial
# 0      0         A/5 21171   7.2500   NaN        S      Mr
# 1      0          PC 17599  71.2833   C85        C     Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Miss
# 3      0            113803  53.1000  C123        S     Mrs
# 4      0            373450   8.0500   NaN        S      Mr

# %%
data.groupby('Initial')[['Age']].mean() #lets check the average age by Initials
# Out:
#                Age
# Initial
# Master    4.574167
# Miss     21.860000
# Mr       32.739609
# Mrs      35.981818
# Other    45.888889

# %% [markdown]
# Filling null age values

# %%
## Assigning the NaN Values with the Ceil values of the mean ages
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
# 41           42         0       2
# 42           43         0       3
# 43           44         1       2
# 44           45         1       3
# 45           46         0       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 49           50         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male  33.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male  33.0      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female  36.0      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male  33.0      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female  22.0      0
# 29                                Todoroff, Mr. Lalio    male  33.0      0
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female  36.0      1
# 32                           Glynn, Miss. Mary Agatha  female  22.0      0
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                     Holverson, Mr. Alexander Oskar    male  42.0      1
# 36                                   Mamee, Mr. Hanna    male  33.0      0
# 37                           Cann, Mr. Ernest Charles    male  21.0      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.0      2
# 39                        Nicola-Yarred, Miss. Jamila  female  14.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 42                                Kraeff, Mr. Theodor    male  33.0      0
# 43           Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 44                      Devaney, Miss. Margaret Delia  female  19.0      0
# 45                           Rogers, Mr. William John    male  33.0      0
# 46                                  Lennon, Mr. Denis    male  33.0      1
# 47                          O'Driscoll, Miss. Bridget  female  22.0      0
# 48                                Samaan, Mr. Youssef    male  33.0      2
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
#
#     Parch            Ticket      Fare        Cabin Embarked Initial
# 0       0         A/5 21171    7.2500          NaN        S      Mr
# 1       0          PC 17599   71.2833          C85        C     Mrs
# 2       0  STON/O2. 3101282    7.9250          NaN        S    Miss
# 3       0            113803   53.1000         C123        S     Mrs
# 4       0            373450    8.0500          NaN        S      Mr
# 5       0            330877    8.4583          NaN        Q      Mr
# 6       0             17463   51.8625          E46        S      Mr
# 7       1            349909   21.0750          NaN        S  Master
# 8       2            347742   11.1333          NaN        S     Mrs
# 9       0            237736   30.0708          NaN        C     Mrs
# 10      1           PP 9549   16.7000           G6        S    Miss
# 11      0            113783   26.5500         C103        S    Miss
# 12      0         A/5. 2151    8.0500          NaN        S      Mr
# 13      5            347082   31.2750          NaN        S      Mr
# 14      0            350406    7.8542          NaN        S    Miss
# 15      0            248706   16.0000          NaN        S     Mrs
# 16      1            382652   29.1250          NaN        Q  Master
# 17      0            244373   13.0000          NaN        S      Mr
# 18      0            345763   18.0000          NaN        S     Mrs
# 19      0              2649    7.2250          NaN        C     Mrs
# 20      0            239865   26.0000          NaN        S      Mr
# 21      0            248698   13.0000          D56        S      Mr
# 22      0            330923    8.0292          NaN        Q    Miss
# 23      0            113788   35.5000           A6        S      Mr
# 24      1            349909   21.0750          NaN        S    Miss
# 25      5            347077   31.3875          NaN        S     Mrs
# 26      0              2631    7.2250          NaN        C      Mr
# 27      2             19950  263.0000  C23 C25 C27        S      Mr
# 28      0            330959    7.8792          NaN        Q    Miss
# 29      0            349216    7.8958          NaN        S      Mr
# 30      0          PC 17601   27.7208          NaN        C      Mr
# 31      0          PC 17569  146.5208          B78        C     Mrs
# 32      0            335677    7.7500          NaN        Q    Miss
# 33      0        C.A. 24579   10.5000          NaN        S      Mr
# 34      0          PC 17604   82.1708          NaN        C      Mr
# 35      0            113789   52.0000          NaN        S      Mr
# 36      0              2677    7.2292          NaN        C      Mr
# 37      0        A./5. 2152    8.0500          NaN        S      Mr
# 38      0            345764   18.0000          NaN        S    Miss
# 39      0              2651   11.2417          NaN        C    Miss
# 40      0              7546    9.4750          NaN        S     Mrs
# 41      0             11668   21.0000          NaN        S     Mrs
# 42      0            349253    7.8958          NaN        C      Mr
# 43      2     SC/Paris 2123   41.5792          NaN        C    Miss
# 44      0            330958    7.8792          NaN        Q    Miss
# 45      0   S.C./A.4. 23567    8.0500          NaN        S      Mr
# 46      0            370371   15.5000          NaN        Q      Mr
# 47      0             14311    7.7500          NaN        Q    Miss
# 48      0              2662   21.6792          NaN        C      Mr
# 49      0            349237   17.8000          NaN        S     Mrs

# %%
data.Age.isnull().any()
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# Observations:
# 1)The Childrens(age<5) were saved in large numbers(The Women and Child First Policy).
#
# 2)The oldest Passenger was saved(80 years).
#
# 3)Maximum number of deaths were in the age group of 30-40.

# %%
sns.catplot(x='Pclass',y='Survived',col='Initial',data=data)
plt.show()

# %% [markdown]
# EMbarked categorical value

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_7c361_row0_col0, #T_7c361_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_7c361_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_7c361_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_7c361_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_7c361_row0_col4, #T_7c361_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_7c361_row1_col0, #T_7c361_row3_col0, #T_7c361_row3_col1, #T_7c361_row3_col2, #T_7c361_row3_col3, #T_7c361_row3_col4, #T_7c361_row4_col0, #T_7c361_row4_col2, #T_7c361_row4_col3, #T_7c361_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_7c361_row1_col1, #T_7c361_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_7c361_row1_col3, #T_7c361_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_7c361_row2_col0, #T_7c361_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_7c361_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_7c361_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_7c361_row2_col4, #T_7c361_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_7c361_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_7c361_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_7c361_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_7c361_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_7c361_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_7c361_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_7c361_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_7c361_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_7c361_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_7c361_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_7c361_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_7c361_row7_col3, #T_7c361_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_7c361_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_7c361_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_7c361_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_7c361_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_7c361_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_7c361_row9_col0, #T_7c361_row9_col1, #T_7c361_row9_col2, #T_7c361_row9_col3, #T_7c361_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7c361">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_7c361_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_7c361_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_7c361_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_7c361_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_7c361_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_7c361_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_7c361_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_7c361_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c361_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_7c361_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_7c361_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7c361_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_7c361_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_7c361_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_7c361_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_7c361_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_7c361_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_7c361_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_7c361_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_7c361_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_7c361_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_7c361_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_7c361_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_7c361_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_7c361_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_7c361_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_7c361_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_7c361_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_7c361_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_7c361_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_7c361_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_7c361_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_7c361_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_7c361_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7c361_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_7c361_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_7c361_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_7c361_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_7c361_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_7c361_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7c361_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_7c361_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_7c361_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_7c361_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_7c361_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_7c361_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_7c361_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_7c361_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_7c361_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_7c361_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_7c361_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_7c361_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_7c361_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_7c361_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_7c361_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_7c361_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_7c361_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_7c361_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_7c361_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_7c361_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_7c361_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_7c361_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_7c361_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_7c361_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_7c361_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_7c361_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_7c361_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_7c361_row9_col0" class="data row9 col0" >81</td>
#       <t

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_4c78a_row0_col0, #T_4c78a_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_4c78a_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_4c78a_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_4c78a_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_4c78a_row0_col4, #T_4c78a_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_4c78a_row1_col0, #T_4c78a_row3_col0, #T_4c78a_row3_col1, #T_4c78a_row3_col2, #T_4c78a_row3_col3, #T_4c78a_row3_col4, #T_4c78a_row4_col0, #T_4c78a_row4_col2, #T_4c78a_row4_col3, #T_4c78a_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_4c78a_row1_col1, #T_4c78a_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_4c78a_row1_col3, #T_4c78a_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_4c78a_row2_col0, #T_4c78a_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_4c78a_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_4c78a_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_4c78a_row2_col4, #T_4c78a_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_4c78a_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_4c78a_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_4c78a_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_4c78a_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_4c78a_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_4c78a_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_4c78a_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_4c78a_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_4c78a_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_4c78a_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_4c78a_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_4c78a_row7_col3, #T_4c78a_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_4c78a_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_4c78a_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_4c78a_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_4c78a_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_4c78a_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_4c78a_row9_col0, #T_4c78a_row9_col1, #T_4c78a_row9_col2, #T_4c78a_row9_col3, #T_4c78a_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4c78a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_4c78a_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_4c78a_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_4c78a_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_4c78a_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_4c78a_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_4c78a_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_4c78a_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_4c78a_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c78a_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_4c78a_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_4c78a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_4c78a_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_4c78a_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_4c78a_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_4c78a_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_4c78a_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_4c78a_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_4c78a_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_4c78a_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_4c78a_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_4c78a_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_4c78a_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_4c78a_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_4c78a_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_4c78a_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_4c78a_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_4c78a_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_4c78a_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_4c78a_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_4c78a_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_4c78a_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_4c78a_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_4c78a_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_4c78a_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_4c78a_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_4c78a_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_4c78a_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_4c78a_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_4c78a_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_4c78a_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_4c78a_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_4c78a_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_4c78a_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_4c78a_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_4c78a_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_4c78a_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_4c78a_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_4c78a_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_4c78a_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_4c78a_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_4c78a_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_4c78a_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_4c78a_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_4c78a_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_4c78a_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_4c78a_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_4c78a_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_4c78a_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_4c78a_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_4c78a_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_4c78a_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_4c78a_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_4c78a_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_4c78a_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_4c78a_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_4c78a_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_4c78a_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_4c78a_row9_col0" class="data row9 col0" >81</td>
#       <t

# %%
d=data.groupby('Embarked')[['Survived']].mean() #lets check the average age by Initials
d
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %% [markdown]
# The chances for survival for Port C is highest around(55%) while it is lowest for S(34%).

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot(x='Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot(x='Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot(x='Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot(x='Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %% [markdown]
# data.groupby(['Embarked','Sex'])[['Survived','Pclass']].mean()

# %%
data.groupby(['Embarked','Sex'])[['Survived','Pclass']].mean()
# Out:
#                  Survived    Pclass
# Embarked Sex
# C        female  0.876712  1.726027
#          male    0.305263  2.010526
# Q        female  0.750000  2.888889
#          male    0.073171  2.926829
# S        female  0.692683  2.185366
#          male    0.174603  2.421769

# %%
temp=data.groupby(['Initial'])[['Fare']].count()/len(data)
temp
# Out:
#              Fare
# Initial
# Master   0.044893
# Miss     0.208754
# Mr       0.593715
# Mrs      0.142536
# Other    0.010101

# %%
temp=data.groupby(['Initial'])[['Fare']].count()/len(data)
temp_df = temp[temp>=0.04].index

temp_df
# Out:
# Index(['Master', 'Miss', 'Mr', 'Mrs', 'Other'], dtype='object', name='Initial')

# %%
data['Embarked'].fillna('S',inplace=True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %% [markdown]
# # sibsip discrete feature

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_e41b3_row0_col0, #T_e41b3_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_e41b3_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_e41b3_row1_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_e41b3_row2_col0, #T_e41b3_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_e41b3_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_e41b3_row3_col0, #T_e41b3_row3_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_e41b3_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_e41b3_row5_col0, #T_e41b3_row5_col1, #T_e41b3_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_e41b3_row6_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_e41b3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_e41b3_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e41b3_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e41b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e41b3_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_e41b3_row0_col1" class="data row0 col1" >210</td>
#     </tr>
#     <tr>
#       <th id="T_e41b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e41b3_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_e41b3_row1_col1" class="data row1 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_e41b3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e41b3_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_e41b3_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_e41b3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e41b3_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_e41b3_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e41b3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e41b3_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_e41b3_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e41b3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e41b3_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_e41b3_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e41b3_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_e41b3_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_e41b3_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(figsize=(12,12))
sns.barplot(x='SibSp',y='Survived',data=data,ax=ax)
ax.set_title('SibSp vs Survived')

plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_1c5c0_row0_col0, #T_1c5c0_row0_col1, #T_1c5c0_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_1c5c0_row1_col0 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_1c5c0_row1_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_1c5c0_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_1c5c0_row2_col0, #T_1c5c0_row4_col2 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_1c5c0_row2_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_1c5c0_row2_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_1c5c0_row3_col0, #T_1c5c0_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_1c5c0_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_1c5c0_row4_col0, #T_1c5c0_row4_col1, #T_1c5c0_row5_col0, #T_1c5c0_row5_col1, #T_1c5c0_row5_col2, #T_1c5c0_row6_col0, #T_1c5c0_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_1c5c0_row6_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_1c5c0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_1c5c0_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_1c5c0_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_1c5c0_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c5c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1c5c0_row0_col0" class="data row0 col0" >137</td>
#       <td id="T_1c5c0_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_1c5c0_row0_col2" class="data row0 col2" >351</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1c5c0_row1_col0" class="data row1 col0" >71</td>
#       <td id="T_1c5c0_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_1c5c0_row1_col2" class="data row1 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1c5c0_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_1c5c0_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_1c5c0_row2_col2" class="data row2 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1c5c0_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_1c5c0_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_1c5c0_row3_col2" class="data row3 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1c5c0_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_1c5c0_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_1c5c0_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1c5c0_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_1c5c0_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_1c5c0_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_1c5c0_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_1c5c0_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_1c5c0_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_1c5c0_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Observations:
# The barplot shows that if a passenger is alone onboard with no siblings, he have 34.5% survival rate. The graph roughly decreases if the number of siblings increase. This makes sense. That is, if I have a family on board, I will try to save them instead of saving myself first. Surprisingly the survival for families with 5-8 members is 0%. The reason may be Pclass??
#
# The reason is Pclass. The crosstab shows that Person with SibSp>3 were all in Pclass3. It is imminent that all the large families in Pclass3(>3) died.
#
# Parch

# %%
pd.crosstab(data.Parch,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_fe725_row0_col0, #T_fe725_row0_col1, #T_fe725_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_fe725_row1_col0 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_fe725_row1_col1 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_fe725_row1_col2 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_fe725_row2_col0 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_fe725_row2_col1 {
#   background-color: #e1f066;
#   color: #000000;
# }
# #T_fe725_row2_col2 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_fe725_row3_col0, #T_fe725_row4_col1, #T_fe725_row5_col0, #T_fe725_row5_col1, #T_fe725_row6_col0, #T_fe725_row6_col1, #T_fe725_row6_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_fe725_row3_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_fe725_row3_col2, #T_fe725_row4_col0, #T_fe725_row4_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_fe725_row5_col2 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# </style>
# <table id="T_fe725">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_fe725_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_fe725_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_fe725_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parch</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe725_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe725_row0_col0" class="data row0 col0" >163</td>
#       <td id="T_fe725_row0_col1" class="data row0 col1" >134</td>
#       <td id="T_fe725_row0_col2" class="data row0 col2" >381</td>
#     </tr>
#     <tr>
#       <th id="T_fe725_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fe725_row1_col0" class="data row1 col0" >31</td>
#       <td id="T_fe725_row1_col1" class="data row1 col1" >32</td>
#       <td id="T_fe725_row1_col2" class="data row1 col2" >55</td>
#     </tr>
#     <tr>
#       <th id="T_fe725_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fe725_row2_col0" class="data row2 col0" >21</td>
#       <td id="T_fe725_row2_col1" class="data row2 col1" >16</td>
#       <td id="T_fe725_row2_col2" class="data row2 col2" >43</td>
#     </tr>
#     <tr>
#       <th id="T_fe725_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fe725_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_fe725_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_fe725_row3_col2" class="data row3 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_fe725_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fe725_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_fe725_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_fe725_row4_col2" class="data row4 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_fe725_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fe725_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_fe725_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_fe725_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_fe725_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fe725_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_fe725_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_fe725_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The crosstab again shows that larger families were in Pclass3.

# %%
f,ax=plt.subplots(figsize=(10,10))
sns.barplot(x='Parch',y='Survived',data=data,ax=ax)
ax.set_title('Parch vs Survived')
plt.show()

# %% [markdown]
# Observations:
# Here too the results are quite similar. Passengers with their parents onboard have greater chance of survival. It however reduces as the number goes up.
#
# The chances of survival is good for somebody who has 1-3 parents on the ship. Being alone also proves to be fatal and the chances for survival decreases when somebody has >4 parents on the ship.

# %% [markdown]
# # Fare contonuos features

# %%
print('Highest Fare was:',data['Fare'].max())
print('Lowest Fare was:',data['Fare'].min())
print('Average Fare was:',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.204207968574636

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()
# Out:
# C:\Users\johnm\AppData\Local\Temp\ipykernel_20996\2377214865.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
# C:\Users\johnm\AppData\Local\Temp\ipykernel_20996\2377214865.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
# C:\Users\johnm\AppData\Local\Temp\ipykernel_20996\2377214865.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])

# %% [markdown]
# Observations in a Nutshell for all features
# Sex: The chance of survival for women is high as compared to men.
#
# Pclass:There is a visible trend that being a 1st class passenger gives you better chances of survival. The survival rate for Pclass3 is very low. For women, the chance of survival from Pclass1 is almost 1 and is high too for those from Pclass2. Money Wins!!!.
#
# Age: Children less than 5-10 years do have a high chance of survival. Passengers between age group 15 to 35 died a lot.
#
# Embarked: This is a very interesting feature. The chances of survival at C looks to be better than even though the majority of Pclass1 passengers got up at S. Passengers at Q were all from Pclass3.
#
# Parch+SibSp: Having 1-2 siblings,spouse on board or 1-3 Parents shows a greater chance of probablity rather than being alone or having a large family travelling with you.

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# Interpreting The Heatmap
# The first thing to note is that only the numeric features are compared as it is obvious that we cannot correlate between alphabets or strings. Before understanding the plot, let us see what exactly correlation is.
#
# POSITIVE CORRELATION: If an increase in feature A leads to increase in feature B, then they are positively correlated. A value 1 means perfect positive correlation.
#
# NEGATIVE CORRELATION: If an increase in feature A leads to decrease in feature B, then they are negatively correlated. A value -1 means perfect negative correlation.
#
# Now lets say that two features are highly or perfectly correlated, so the increase in one leads to increase in the other. This means that both the features are containing highly similar information and there is very little or no variance in information. This is known as MultiColinearity as both of them contains almost the same information.
#
# So do you think we should use both of them as one of them is redundant. While making or training models, we should try to eliminate redundant features as it reduces training time and many such advantages.
#
# Now from the above heatmap,we can see that the features are not much correlated. The highest correlation is between SibSp and Parch i.e 0.41. So we can carry on with all features.
